# %% [markdown]
# # Quality of water and life
# By continuing looking at the positives of the increase in industry we can see that the water quality is increasing in a lot of countries that see an increase in industry. Basic water facilities are one of the basics of hygiene and health.
#
# Looking at the figure it is clear to see that countries like China and India have seen a great improvement in water quality. A lot of countries near the ocean in Africa also see the improvement, going from terrible to pretty decent. This is thanks to the increase in infrastructure that is needed for the industry.

# %%
# %store -r fig_basic
# %store -r fig_life

fig_basic.show()

# %% [markdown]
# It is important to note that all the countries in Europe have a national basic water quality of well over 90, with most big countries having a near perfect 99 score. Scores from 85 and up are considered okay.

# %% [markdown]
# Another positive that comes with this is an increase in life expectancy, although life expectancy increases slowly over the years, it is clear that countries like India, Brazil, Russia and many countries in Africa have increased their life expectancy. This is all thanks to the growing world wide industry and connection of the world. Sanitation and health care becomes much more available thanks to the connection of countries.

# %%
fig_life.show()
