# %% [markdown]
# # First arguments (working title)
#
# With industry it is understandable that plenty of advanced infrastructure must follow. Things such as airports, regular ports, train stations and railroads, and motorways and roads are all natural results of an advancing society. These improvements in local infrastructure are a direct sign of an increase in wealth since you would rarely see dirt and gravel roads in an advance first world country. As more and more infrastructure is installed within a country said country often finds itself in the position of being able to shape the rest of its land in whatever way it pleases bringing plenty of other features to its nation.
#
# These features include things such as man-made waterways and lakes, parks, other facilities, but also man-made forest and nature reserves. A problem that still shows itself however is that of the decline of wooded area's in countries with improved infrastructure. Many things but mainly roads and motorways take up space that once belonged to forests and their inhabitants as the following figure shows.

# %%
# %store -r fig4
# %store -r fig5

fig4.show()
# Out:
# <div>                            <div id="c0a0e34c-eff3-424e-b8b6-b25e931b7e06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0a0e34c-eff3-424e-b8b6-b25e931b7e06")) {                    Plotly.newPlot(                        "c0a0e34c-eff3-424e-b8b6-b25e931b7e06",                        [{"dimensions":[{"categoryarray":["Lots of vegetation","Moderate vegetation","Bare vegetation"],"categoryorder":"array","label":"Forest","values":["Moderate vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetati
# ...

# %% [markdown]
# This figure shows the relation between the amount of wooded land and the density of roads within a country. As the data shows, as more road is built the total percentage of forests to the total surface area of countries declines. In countries with less roads the opposite is true as there is more forest on average. This therefore provides prove that infrastructure and by proxy an increase in industry is a true detriment to the environment.
#
# This however is not the full story as the following figure shows.

# %%
fig5.show()
# Out:
# <div>                            <div id="87c40489-4f43-4411-97ad-55f0d771199d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87c40489-4f43-4411-97ad-55f0d771199d")) {                    Plotly.newPlot(                        "87c40489-4f43-4411-97ad-55f0d771199d",                        [{"dimensions":[{"categoryarray":["Lots of vegetation","Moderate vegetation","Bare vegetation"],"categoryorder":"array","label":"Forest","values":["Moderate vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetati
# ...

# %% [markdown]
# If the total amount of artificial surface is added to the equation these figures tell a slightly different story. Artificial surface refers to any surface of land which has been shaped and modeled by humanity without taking roads and railroads into account. This artificial surface is anything from concrete foundations to forests planted by humans. If there are less roads in a country there is more artificial land and if there are more roads there is less artificial land. An explanation for this could very well be that in more developed countries more land is being acquitted to nature preserves and hand-made forests instead of motorways and roads. The opposite is then also true, with more roads less money and land is being spent on the preservation of nature. Only looking at the relation between two things can paint an incomplete picture of a situation.
