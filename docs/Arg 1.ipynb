# %% [markdown]
# # Industry, infrastructure, and nature.
#
# With industry it is understandable that plenty of advanced infrastructure must follow. Things such as airports, regular ports, train stations and railroads, motorways, and roads are all natural results of an advancing society. These improvements in local infrastructure are a direct sign of an increase in wealth since you would rarely see dirt and gravel roads in an advanced first world country. As more and more infrastructure is installed within a country said country often finds itself in the position of being able to shape the rest of its land in whatever way it pleases bringing plenty of other features to its nation.
#
# It might therefore be interesting to investigate just how a rise in industry and infrastructure might affect local nature.

# %%
# %store -r fig4
# %store -r fig5

fig4.show()
# Out:
# <div>                            <div id="74ec95c2-3b01-4989-84db-505dcad2d95e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74ec95c2-3b01-4989-84db-505dcad2d95e")) {                    Plotly.newPlot(                        "74ec95c2-3b01-4989-84db-505dcad2d95e",                        [{"dimensions":[{"categoryarray":["Lots of vegetation","Moderate vegetation","Bare vegetation"],"categoryorder":"array","label":"Natural and semi-natural vegetated land, % total","values":["Moderate vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare ve
# ...

# %% [markdown]
# From this figure a conclusion could be drawn concerning a decline in vegetated land as the local density of road increases. This must then mean that a rise in industry and infrastructure is nothing but a bad influence to local nature.
#
# This however is not the full story as the following figure shows.

# %%
fig5.show()
# Out:
# <div>                            <div id="41707f4f-1d27-48a8-9fc9-ff85d9349dc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41707f4f-1d27-48a8-9fc9-ff85d9349dc5")) {                    Plotly.newPlot(                        "41707f4f-1d27-48a8-9fc9-ff85d9349dc5",                        [{"dimensions":[{"categoryarray":["Lots of vegetation","Moderate vegetation","Bare vegetation"],"categoryorder":"array","label":"Natural and semi-natural vegetated land, % total","values":["Moderate vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Lots of vegetation","Bare vegetation","Bare vegetation","Bare vegetation","Bare ve
# ...

# %% [markdown]
# If the total amount of artificial surface is added to the equation these figures tell a slightly different story. Artificial surface refers to any surface of land which has been shaped and modeled by humanity without taking roads and railroads into account. This artificial surface is anything from concrete foundations to forests planted by humans. If there are less roads in a country there is more artificial land and if there are more roads there is less artificial land. An explanation for this could very well be that in more developed countries more land is being acquitted to nature preserves and hand-made forests instead of motorways and roads. The opposite is then also true, with more roads less money and land is being spent on the preservation of nature. Only looking at the relation between two things can paint an incomplete picture of a situation, but by looking at multiple factors it is possible to get a reasonable idea of a country's industry and infrastructure.
#
# Due to the complex nature of this particular view it might be a better idea to look at a different way of measuring the effects of industry.
